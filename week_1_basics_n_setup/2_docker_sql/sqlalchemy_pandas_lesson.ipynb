# %%
import pandas as pd
# from pyarrow.parquet import ParquetFile
# import pyarrow as pa
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://tswayzee:troy@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
conn = engine.raw_connection()

# %%
pf = ParquetFile('yellow_tripdata_2022-01.parquet') 
first_ten_rows = next(pf.iter_batches(batch_size = 10))
df = pa.Table.from_batches([first_ten_rows]).to_pandas()

# %%
df
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1         1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2         2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3         2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4         2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# 5         1  2022-01-01 00:40:15   2022-01-01 01:09:48              1.0
# 6         2  2022-01-01 00:20:50   2022-01-01 00:34:58              1.0
# 7         2  2022-01-01 00:13:04   2022-01-01 00:22:45              1.0
# 8         2  2022-01-01 00:30:02   2022-01-01 00:44:49              1.0
# 9         2  2022-01-01 00:48:52   2022-01-01 00:53:28              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.80         1.0                  N           142           236
# ...

# %%
df_iter = pd.read_parquet('yellow_tripdata_2022-01.parquet', engine='pyarrow', iterator=True, chunksize=100000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df_iter = pd.read_parquet('yellow_tripdata_2022-01.parquet', iterator=True, chunksize=100000)
#
# File /usr/local/lib/python3.9/site-packages/pandas/io/parquet.py:503, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     456 """
#     457 Load a parquet object from the file path, returning a DataFrame.
#     458
#    (...)
#     499 DataFrame
#     500 """
#     501 impl = get_engine(engine)
# --> 503 return impl.read(
#     504     path,
#     505     columns=columns,
#     506     storage_options=storage_options,
#     507     use_nullable_dtypes=use_nullable_dtypes,
#     508     **kwargs,
#     509 )
#
# ...

# %%
df = pd.read_csv('yellow_tripdata_2021-01.csv.gz', nrows=100)

# %%
df
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47                1
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03                2
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25                2
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44                1
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41                3
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv.gz', iterator=True, chunksize=100000)

# %%
df = next(df_iter)
len(df)
# Out:
# 100000

# %%
df.head(n=0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge]
# Index: []

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 2.9 s, sys: 93.8 ms, total: 3 s
# Wall time: 5.93 s
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    
    df = next(df_iter)
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
    t_end = time()
    
    print(f'inserted another chunk, took {t_end - t_start} seconds')
# Out:
# inserted another chunk, took 6.25432014465332 seconds
# inserted another chunk, took 5.214476108551025 seconds
# inserted another chunk, took 5.300015926361084 seconds
# inserted another chunk, took 5.297256946563721 seconds
# inserted another chunk, took 5.2739598751068115 seconds
# inserted another chunk, took 5.412549018859863 seconds
# inserted another chunk, took 5.8260626792907715 seconds
# inserted another chunk, took 5.418767690658569 seconds
# inserted another chunk, took 5.568508863449097 seconds
# inserted another chunk, took 5.561886310577393 seconds
# inserted another chunk, took 5.396040916442871 seconds
# /var/folders/c3/r_4cj39j3d9171vn6cwl_8y80000gn/T/ipykernel_46823/3463307480.py:4: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# inserted another chunk, took 5.442363977432251 seconds
# inserted another chunk, took 3.260172128677368 seconds
# ...

# %%
engine.dispose()
